# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# We are a group of data scientist working for the national College Board who is responsible for developing and administering national-wide SAT/ACT test. In addition, the College Board also provide resources and services to students, colleges and universities in educational planning, adission and financial aid.
#
# The College Board has tasked us to explore if there is a correlation between real GDP per capita and SAT/ACT scores and participation rate, and whether states with higher real GDP per capita produce higher scoring results. This would allow the College Board to determine if additional resources are required to students from lower income states to boost their scores as well as increasing participation rate.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# On the other hand, there were several states with mandanted SAT/ACT. In 2017, Colorado and Illinois mandated SAT in 2017 and still remained ([*source*](https://testive.com/colorado-sat-change-2017/)). In beginning of 2022, students are Indiana are required to take SAT in order to graduate. The policy of how SAT/ACT are conducted or enforced differs among states ([*source*](https://www.edweek.org/teaching-learning/what-tests-does-each-state-require)).

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*
#
# The following datasets will be used for this analysis:
# * `act_2017.csv`
#     - ACT participation rate, english, math, reading, science and composite score, by state for 2017
# * `act_2018.csv`
#     - ACT participation rate and composite score, by state for 2018
# * `act_2019.csv`
#     - ACT participation rate and composite score, by state for 2019
# * `sat_2017.csv`
#     - SAT participation rate evidence-based reading and writing, math and total score, by state for 2017
# * `sat_2018.csv`
#     - SAT participation rate evidence-based reading and writing, math and total score, by state for 2018
# * `sat_2019.csv`
#     - SAT participation rate evidence-based reading and writing, math and total score, by state for 2019
# * `US_GDP.csv` (additional dataset)
#     - GDP of US, by state from 2017 to 2019
# * `population.csv` (additional dataset)
#     -  Population of US by state from 2017 to 2019

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **To-Do:** *Fill out this cell with outside research or any additional background information that will support your analysis.*
#
# A study has shown that the educational achievement gap among students of difference income groups is severe. Students who come from a low income family tend to perform worse. However, it is also observed that the achievement gap could be due to many other factors such as the performance of the school systems and it is much debated of how the SAT/ACT is interpreted to seek a test performance of an individual([*source*](https://www.mckinsey.com/industries/education/our-insights/the-economic-cost-of-the-us-education-gap)). These factors could include percentage of minority in the state, unemployment rate or per pupil expenditure ([*source*](https://www.jstor.org/stable/1434706)).

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def find_mean(value):
    """
    Find mean in a list of values
    """
    mean = sum(value)/len(value)
    return mean

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def std_dev(value):
    """
    Find standard deviation in a list of value
    """
    n = len(value)           # get the number of entries
    mean = sum(value) / n    # get mean
    var = sum((x - mean)**2 for x in value) / n # get variance
    std_dev = var ** 0.5     # calculate std dev
    return std_dev

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
def percent_to_float(value):
    """
    Convert string percentage to float
    """
    return float(value.strip('%'))/100

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy.stats as stats

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcdef string_to_float(value):
#     """
#     Convert population string to int
#     """
#     return float(value.replace(',',''))ome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
def string_to_float(value):
    """
    Convert population string to int
    """
    return float(value.replace(',',''))

# %%
# Import dataset
act_2017 = pd.read_csv('./data/act_2017.csv')
act_2018 = pd.read_csv('./data/act_2018.csv')
act_2019 = pd.read_csv('./data/act_2019.csv')
sat_2017 = pd.read_csv('./data/sat_2017.csv')
sat_2018 = pd.read_csv('./data/sat_2018.csv')
sat_2019 = pd.read_csv('./data/sat_2019.csv')
gdp_state = pd.read_csv('./data/us_gdp.csv')
population = pd.read_csv('./data/population.csv')

# %%
# Display first 5 rows of ACT 2017
act_2017.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
# Display first 5 rows of SAT 2017
sat_2017.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
# Determine shape of ACT 2017 to 2019
print(act_2017.shape)
print(act_2018.shape)
print(act_2019.shape)
# Out:
# (52, 7)
# (52, 3)
# (52, 3)

# %%
# Determine shape of SAT 2017 to 2019
print(sat_2017.shape)
print(sat_2018.shape)
print(sat_2019.shape)
# Out:
# (51, 5)
# (51, 5)
# (53, 5)

# %% [markdown]
# #### Check for missing values

# %%
# Check for missing values. At the same time, verify any columns need to be renamed
print("Check for missing values\n")
print(f"act_2017\n{act_2017.isnull().sum()}\n")
print(f"act_2018\n{act_2018.isnull().sum()}\n")
print(f"act_2019\n{act_2019.isnull().sum()}\n")
print(f"sat_2017\n{sat_2017.isnull().sum()}\n")
print(f"sat_2018\n{sat_2018.isnull().sum()}\n")
print(f"sat_2019\n{sat_2019.isnull().sum()}\n")
# Out:
# Check for missing values
#
# act_2017
# State            0
# Participation    0
# English          0
# Math             0
# Reading          0
# Science          0
# Composite        0
# dtype: int64
#
# act_2018
# State            0
# Participation    0
# Composite        0
# dtype: int64
#
# act_2019
# State            0
# Participation    0
# Composite        0
# dtype: int64
#
# sat_2017
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64
#
# sat_2018
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64
#
# sat_2019
# State                 0
# Participation Rate    0
# EBRW                  0
# Math                  0
# ...

# %% [markdown]
# Observation:
# * There are no missing values in the dataframe. However, several columns in SAT 2017 to 2019 are observed to use a different name for the same label, namely the "Evidence-Based Reading and Writing" or "EBRW". These will be renamed in the subsequent code.
# * Secondly, it is observed that ACT 2018 and 2019 are missing the English, Math, Reading and Science columns that are seen in ACT 2017.
# * Lastly, it is observed that the number of columns in SAT 2019 has two additional rows compared to 2017 and 2018. The additional rows will be explored later

# %% [markdown]
# #### Renaming columns

# %%
def make_col_lowercase(df):
    """
    Convert all header column to lower case
    """
    df.columns = [x.lower() for x in df.columns]

# %%
# Change all columns of dataframe to lowercase
make_col_lowercase(act_2017)
make_col_lowercase(act_2018)
make_col_lowercase(act_2019)
make_col_lowercase(sat_2017)
make_col_lowercase(sat_2018)
make_col_lowercase(sat_2019)
make_col_lowercase(sat_2019)

# %%
# Verify that columns are changed to lowercase
act_2017.columns
# Out:
# Index(['state', 'participation', 'english', 'math', 'reading', 'science',
#        'composite'],
#       dtype='object')

# %%
# Rename column for "evidence-based reading and writing" to "ebrw"
sat_2017.rename(columns = {'evidence-based reading and writing':'ebrw'}, inplace = True)
sat_2018.rename(columns = {'evidence-based reading and writing':'ebrw'}, inplace = True)
sat_2019.rename(columns = {'participation rate':'participation'}, inplace = True)

# %%
# Verify that all columns are correctly renamed
print(sat_2017.columns)
print(sat_2018.columns)
print(sat_2019.columns)
# Out:
# Index(['state', 'participation', 'ebrw', 'math', 'total'], dtype='object')
# Index(['state', 'participation', 'ebrw', 'math', 'total'], dtype='object')
# Index(['state', 'participation', 'ebrw', 'math', 'total'], dtype='object')

# %% [markdown]
# #### Check for issues with the observations

# %%
print(f"act_2017 \n{act_2017.describe()}\n")
print(f"act_2018 \n{act_2018.describe()}\n")
print(f"act_2019 \n{act_2019.describe()}\n")
print(f"sat_2017 \n{sat_2017.describe()}\n")
print(f"sat_2018 \n{sat_2018.describe()}\n")
print(f"sat_2019 \n{sat_2019.describe()}\n")
# Out:
# act_2017
#          english       math    reading    science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000
#
# act_2018
#        composite
# count  52.000000
# mean   21.544231
# std     2.119417
# min    17.700000
# 25%    19.975000
# 50%    21.300000
# 75%    23.725000
# max    25.600000
#
# act_2019
#        composite
# count  52.000000
# mean   21.450000
# std     2.175487
# min    17.900000
# 25%    19.800000
# 50%    20.950000
# 75%    23.650000
# max    25.500000
#
# sat_2017
#              ebrw        math        total
# count   51.000000   51.000000    51.000000
# mean   569.117647  547.627451  1126.098039
# ...

# %% [markdown]
# Observation:
# * All values within the ACT and SAT scores falls within the range and no outliers are seen

# %%
# Based on earlier observation, we see that SAT 2019 has two additional columns
# The code below narrows down the additional column and they will be dropped
print(f"{pd.concat([sat_2018,sat_2019]).drop_duplicates(subset = 'state', keep=False)}\n")
# Out:
#              state participation  ebrw  math  total
# 39     Puerto Rico             —   483   462    944
# 47  Virgin Islands             —   490   445    935

# %%
# Drop Peutro Rico and Virgin Islands rows from SAT 2019
sat_2019 = sat_2019.drop(labels=[39, 47], axis=0)
sat_2019
# Out:
#                    state participation  ebrw  math  total
# 0                Alabama            7%   583   560   1143
# 1                 Alaska           41%   556   541   1097
# 2                Arizona           31%   569   565   1134
# 3               Arkansas            6%   582   559   1141
# 4             California           63%   534   531   1065
# 5               Colorado          100%   518   506   1024
# 6            Connecticut          100%   529   516   1046
# 7               Delaware          100%   499   486    985
# 8   District of Columbia           94%   495   480    975
# 9                Florida          100%   516   483    999
# 10               Georgia           71%   538   519   1058
# 11                Hawaii           54%   550   550   1100
# 12                 Idaho          100%   505   488    993
# 13              Illinois          100%   509   504   1013
# 14               Indiana           66%   543   537   1080
# ...

# %%
# Print datatypes of the df 
print(f"Datatype for act_2017\n{act_2017.dtypes}\n")
print(f"Datatype for act_2018\n{act_2018.dtypes}\n")
print(f"Datatype for act_2019\n{act_2019.dtypes}\n")
print(f"Datatype for sat_2017\n{sat_2017.dtypes}\n")
print(f"Datatype for sat_2018\n{sat_2018.dtypes}\n")
print(f"Datatype for sat_2019\n{sat_2019.dtypes}\n")
# Out:
# Datatype for act_2017
# state             object
# participation     object
# english          float64
# math             float64
# reading          float64
# science          float64
# composite         object
# dtype: object
#
# Datatype for act_2018
# state             object
# participation     object
# composite        float64
# dtype: object
#
# Datatype for act_2019
# state             object
# participation     object
# composite        float64
# dtype: object
#
# Datatype for sat_2017
# state            object
# participation    object
# ebrw              int64
# math              int64
# total             int64
# dtype: object
#
# Datatype for sat_2018
# state            object
# participation    object
# ebrw              int64
# math              int64
# total             int64
# dtype: object
#
# Datatype for sat_2019
# state            object
# participation    object
# ebrw              int64
# math              int64
# total             int64
# dtype: object

# %% [markdown]
# Observation:
# * The column "composite" in ACT 2017 should be a float and not an object/string

# %%
# View unique values of ACT_2017
act_2017["composite"].unique()
# Out:
# array(['21.0', '19.2', '19.8', '19.7', '19.4', '22.8', '20.8', '25.2',
#        '24.1', '24.2', '21.4', '19.0', '22.3', '22.6', '21.9', '21.7',
#        '20.0', '19.5', '24.3', '23.6', '25.4', '21.5', '18.6', '20.4',
#        '20.3', '17.8', '25.5', '23.9', '19.1', '22.0', '21.8', '23.7',
#        '24.0', '18.7', '20.7', '23.8', '20.5', '20.2x'], dtype=object)

# %% [markdown]
# #### Cleaning the data

# %%
# From the act_2017 df, we see a "20.2x" which need to be removed and converted to float.
act_2017["composite"] = act_2017["composite"].str.replace('x', '')
# Verify data is correct
act_2017["composite"].astype("float")
# Out:
# 0     21.0
# 1     19.2
# 2     19.8
# 3     19.7
# 4     19.4
# 5     22.8
# 6     20.8
# 7     25.2
# 8     24.1
# 9     24.2
# 10    19.8
# 11    21.4
# 12    19.0
# 13    22.3
# 14    21.4
# 15    22.6
# 16    21.9
# 17    21.7
# 18    20.0
# 19    19.5
# 20    24.3
# 21    23.6
# 22    25.4
# 23    24.1
# 24    21.5
# 25    18.6
# 26    20.4
# 27    20.3
# 28    21.4
# 29    17.8
# 30    25.5
# 31    23.9
# 32    19.7
# 33    24.2
# 34    19.1
# 35    20.3
# 36    22.0
# 37    19.4
# 38    21.8
# 39    23.7
# 40    24.0
# 41    18.7
# 42    21.8
# 43    19.8
# 44    20.7
# 45    20.3
# 46    23.6
# 47    23.8
# 48    21.9
# 49    20.4
# 50    20.5
# 51    20.2
# Name: composite, dtype: float64

# %%
# Convert all participation column to float using the function defined above
act_2017["participation"] = act_2017["participation"].map(percent_to_float)
act_2018["participation"] = act_2018["participation"].map(percent_to_float)
act_2019["participation"] = act_2019["participation"].map(percent_to_float)
sat_2017["participation"] = sat_2017["participation"].map(percent_to_float)
sat_2018["participation"] = sat_2018["participation"].map(percent_to_float)
sat_2019["participation"] = sat_2019["participation"].map(percent_to_float)

# %% [markdown]
# #### Merging ACT and SAT

# %%
# Merge 2017, 2018 and 2019 act .
act_2017_2018 = pd.merge(act_2017, act_2018, on = "state", 
                         how = "left", suffixes = ("_2017", "_2018"))

act_2017_2018_2019 = pd.merge(act_2017_2018, act_2019, on = "state",
                              how = "left")

act_2017_2018_2019 = act_2017_2018_2019.rename(columns = 
                                               {"participation" : "participation_2019", 
                                                "composite" : "composite_2019"})

# %%
# Drop english, math, reading and science from act and only consider participation and composite
act_all = act_2017_2018_2019.drop(columns=["english", 'math', "reading", "science"])

# Drop District of columbia and National
act_all.drop(act_all[(act_all["state"] == "District of Columbia") | 
            (act_all['state'] == "National")].index, 
             inplace=True)

# Convert composite column to float
act_all["composite_2017"] = act_all["composite_2017"].astype("float")

# %%
# Verify that all columns are converted to the correct datatype
act_all.head(3)
# Out:
#      state  participation_2017  composite_2017  participation_2018  \
# 1  Alabama                1.00            19.2                1.00
# 2   Alaska                0.65            19.8                0.33
# 3  Arizona                0.62            19.7                0.66
#
#    composite_2018  participation_2019  composite_2019
# 1            19.1                1.00            18.9
# 2            20.8                0.38            20.1
# 3            19.2                0.73            19.0

# %%
print(act_all.shape)
act_all.dtypes
# Out:
# (51, 7)
# state                  object
# participation_2017    float64
# composite_2017        float64
# participation_2018    float64
# composite_2018        float64
# participation_2019    float64
# composite_2019        float64
# dtype: object

# %%
# Merge 2017, 2018, 2019 SAT dataframe
sat_2017_2018 = pd.merge(sat_2017, sat_2018, on = "state", how = "outer", suffixes = ("_2017", "_2018"))
sat_2017_2018_2019 = pd.merge(sat_2017_2018, sat_2019, on = "state", how = "outer")
sat_2017_2018_2019 = sat_2017_2018_2019.rename(columns = {"participation" : "participation_2019", 
                                                          "ebrw" : "ebrw_2019", "math" : "math_2019", 
                                                          "total" : "total_2019"})

sat_all = sat_2017_2018_2019

# %%
# Drop District of Columbia row
sat_all.drop(sat_all[(sat_all["state"] == "District of Columbia")].index, 
             inplace=True)

# %%
# Verify that all columns are converted to the correct datatype
sat_all.head(3)
# Out:
#      state  participation_2017  ebrw_2017  math_2017  total_2017  \
# 0  Alabama                0.05        593        572        1165
# 1   Alaska                0.38        547        533        1080
# 2  Arizona                0.30        563        553        1116
#
#    participation_2018  ebrw_2018  math_2018  total_2018  participation_2019  \
# 0                0.06        595        571        1166                0.07
# 1                0.43        562        544        1106                0.41
# 2                0.29        577        572        1149                0.31
#
#    ebrw_2019  math_2019  total_2019
# 0        583        560        1143
# 1        556        541        1097
# 2        569        565        1134

# %%
print(sat_all.shape)
sat_all.dtypes
# Out:
# (50, 13)
# state                  object
# participation_2017    float64
# ebrw_2017               int64
# math_2017               int64
# total_2017              int64
# participation_2018    float64
# ebrw_2018               int64
# math_2018               int64
# total_2018              int64
# participation_2019    float64
# ebrw_2019               int64
# math_2019               int64
# total_2019              int64
# dtype: object

# %% [markdown]
# #### Preparing and merging GDP dataframe

# %%
# View GDP dataframe
print(gdp_state.shape)
gdp_state.head(3)
# Out:
# (60, 4)
#          GeoName        2017        2018        2019
# 0  United States  18079084.0  18606787.0  19032672.0
# 1        Alabama    197566.6    200800.9    203383.9
# 2         Alaska     54129.5     53249.6     53336.5

# %%
# Rename "GeoName" to "state" in GDP_state df to prepare for merge
gdp_state.rename(columns = {"GeoName" : "state",
                            "2017" : "gdp_2017",
                            "2018" : "gdp_2018",
                            "2019" : "gdp_2019"}, inplace = True)

# %%
# Verify that column is renamed
gdp_state.head(3)
# Out:
#            state    gdp_2017    gdp_2018    gdp_2019
# 0  United States  18079084.0  18606787.0  19032672.0
# 1        Alabama    197566.6    200800.9    203383.9
# 2         Alaska     54129.5     53249.6     53336.5

# %%
# Check population df. --> Required to convert string to int
population.dtypes
# Out:
# state    object
# 2017     object
# 2018     object
# 2019     object
# dtype: object

# %%
# Replace all strings in population and convert int
population["2017"] = population["2017"].map(string_to_float)
population["2018"] = population["2018"].map(string_to_float)
population["2019"] = population["2019"].map(string_to_float)

# %%
# Verify the correct datatype
print(population["2017"].dtypes)
print(population["2018"].dtypes)
print(population["2019"].dtypes)
# Out:
# float64
# float64
# float64

# %%
# Merge gdp_state with population to get GDP per capital
gdp_pop = pd.merge(gdp_state, population, how="inner", on="state")
gdp_pop.head()
# Out:
#            state    gdp_2017    gdp_2018    gdp_2019         2017  \
# 0  United States  18079084.0  18606787.0  19032672.0  324985539.0
# 1        Alabama    197566.6    200800.9    203383.9    4874486.0
# 2         Alaska     54129.5     53249.6     53336.5     739700.0
# 3        Arizona    302455.4    313618.7    323894.3    7044008.0
# 4       Arkansas    113885.2    115937.6    116790.9    3001345.0
#
#           2018         2019
# 0  326687501.0  328239523.0
# 1    4887681.0    4903185.0
# 2     735139.0     731545.0
# 3    7158024.0    7278717.0
# 4    3009733.0    3017804.0

# %%
# Column to calculate for GDP per cap
gdp_pop["gdpPerCap_2017"] = gdp_pop["gdp_2017"] / gdp_pop["2017"]
gdp_pop["gdpPerCap_2018"] = gdp_pop["gdp_2018"] / gdp_pop["2018"]
gdp_pop["gdpPerCap_2019"] = gdp_pop["gdp_2019"] / gdp_pop["2019"]

# %%
# Select only gdp per cap columns for 2017, 2018, 2019
gdp_per_cap = gdp_pop[["state", "gdpPerCap_2017", "gdpPerCap_2018", "gdpPerCap_2019" ]]

# %%
# View dataframe
print(gdp_per_cap.shape)
gdp_per_cap.head()
# Out:
# (52, 4)
#            state  gdpPerCap_2017  gdpPerCap_2018  gdpPerCap_2019
# 0  United States        0.055630        0.056956        0.057984
# 1        Alabama        0.040531        0.041083        0.041480
# 2         Alaska        0.073178        0.072435        0.072909
# 3        Arizona        0.042938        0.043814        0.044499
# 4       Arkansas        0.037945        0.038521        0.038701

# %% [markdown]
# #### Merging ACT and SAT with GDP dataframe

# %%
# Merge ACT with GDP and drop any duplicate rows
act_gdp = pd.merge(act_all, gdp_per_cap, how="inner", on="state")
act_gdp.drop_duplicates(subset=["state"], keep="first", inplace=True, ignore_index=True)

# %%
print(act_gdp.shape)
act_gdp.head()
# Out:
# (50, 10)
#         state  participation_2017  composite_2017  participation_2018  \
# 0     Alabama                1.00            19.2                1.00
# 1      Alaska                0.65            19.8                0.33
# 2     Arizona                0.62            19.7                0.66
# 3    Arkansas                1.00            19.4                1.00
# 4  California                0.31            22.8                0.27
#
#    composite_2018  participation_2019  composite_2019  gdpPerCap_2017  \
# 0            19.1                1.00            18.9        0.040531
# 1            20.8                0.38            20.1        0.073178
# 2            19.2                0.73            19.0        0.042938
# 3            19.4                1.00            19.3        0.037945
# 4            22.7                0.23            22.6        0.064580
#
#    gdpPerCap_2018  gdpPerCap_2019
# 0        0.041083        0.041480
# 1        0.072435        0.072909
# ...

# %%
# Merge SAT with GDP
sat_gdp = pd.merge(sat_all, gdp_per_cap, how="inner", on="state")

# %%
# View dataframe
print(sat_gdp.shape)
sat_gdp.head()
# Out:
# (50, 16)
#         state  participation_2017  ebrw_2017  math_2017  total_2017  \
# 0     Alabama                0.05        593        572        1165
# 1      Alaska                0.38        547        533        1080
# 2     Arizona                0.30        563        553        1116
# 3    Arkansas                0.03        614        594        1208
# 4  California                0.53        531        524        1055
#
#    participation_2018  ebrw_2018  math_2018  total_2018  participation_2019  \
# 0                0.06        595        571        1166                0.07
# 1                0.43        562        544        1106                0.41
# 2                0.29        577        572        1149                0.31
# 3                0.05        592        576        1169                0.06
# 4                0.60        540        536        1076                0.63
#
#    ebrw_2019  math_2019  total_2019  gdpPerCap_2017  gdpPerCap_2018  \
# ...

# %% [markdown]
# #### Export merged dataframe

# %%
# Export cleaned table to CSV
act_gdp.to_csv("./data/act_gdp.csv")
sat_gdp.to_csv("./data/sat_gdp.csv")

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# **To-Do:** *Edit the table below to create your own data dictionary for the datasets you chose.*
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|ACT/SAT|The subnational entities under U.S.A|
# |participation|float|ACT/SAT|The percentage of participants under ACT/ SAT|
# |composite|float|ACT|The average of the 4 test scores in ACT|
# |ebrw|int|SAT|The score acheived for Evidence-based Reading and Writing for SAT|
# |math|int|SAT|The score achieved for Math for SAT|
# |total|float|SAT|The sum of the two scores in SAT|
# |gdp_per_cap|float|ACT/SAT|The Gross Domestic Product(GDP) per capita of each state|
# |act_part_change_17_to_18|float|ACT| The change in percentage for ACT between 2017 and 2018
# |act_part_change_18_to_19|float|ACT| The change in percentage for ACT between 2018 and 2019
# |sat_part_change_17_to_18|float|SAT| The change in percentage for SAT between 2017 and 2018
# |act_part_change_18_to_19|float|SAT| The change in percentage for ACT between 2018 and 2019

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# ### Summary Statistic

# %%
# Summary statistic for ACT 2017 to 2019
act_gdp.describe()
# Out:
#        participation_2017  composite_2017  participation_2018  composite_2018  \
# count           50.000000       50.000000           50.000000       50.000000
# mean             0.659200       21.466000            0.623200       21.454000
# std              0.321107        2.004241            0.341141        2.111312
# min              0.080000       17.800000            0.070000       17.700000
# 25%              0.310000       19.800000            0.277500       19.925000
# 50%              0.710000       21.400000            0.660000       21.050000
# 75%              1.000000       23.400000            1.000000       23.650000
# max              1.000000       25.500000            1.000000       25.600000
#
#        participation_2019  composite_2019  gdpPerCap_2017  gdpPerCap_2018  \
# count           50.000000       50.000000       50.000000       50.000000
# mean             0.592000       21.424000        0.052665        0.053643
# ...

# %%
# Dictionary comprehension to apply the standard deviation function for ACT
sd_act = {column: std_dev(act_gdp[column]) for column in act_gdp if column != "state"}
sd_act
# Out:
# {'participation_2017': 0.3178794740149165,
#  'composite_2017': 1.9840977798485642,
#  'participation_2018': 0.33771254048376703,
#  'composite_2018': 2.090091864009809,
#  'participation_2019': 0.3430510166141473,
#  'composite_2019': 2.175183670405789,
#  'gdpPerCap_2017': 0.009743311925452474,
#  'gdpPerCap_2018': 0.010054188953286147,
#  'gdpPerCap_2019': 0.010339751323591821}

# %%
# Summary statistic for SAT 2017 to 2019
sat_gdp.describe()
# Out:
#        participation_2017   ebrw_2017   math_2017   total_2017  \
# count           50.000000   50.000000   50.000000    50.000000
# mean             0.386000  570.860000  549.220000  1129.620000
# std              0.345602   44.385146   84.998269    89.913085
# min              0.020000  503.000000   52.000000   996.000000
# 25%              0.040000  535.250000  523.250000  1057.000000
# 50%              0.340000  559.500000  549.500000  1107.500000
# 75%              0.650000  613.500000  601.000000  1214.000000
# max              1.000000  644.000000  651.000000  1295.000000
#
#        participation_2018   ebrw_2018   math_2018   total_2018  \
# count           50.000000   50.000000   50.000000    50.000000
# mean             0.448200  565.020000  557.760000  1122.880000
# std              0.370976   47.010416   46.987432    92.845634
# min              0.020000  480.000000  486.000000   998.000000
# 25%              0.042500  535.000000  524.250000  1062.250000
# ...

# %%
# Dictionary comprehension to apply the standard deviation function for SAT
sd_sat = {column: std_dev(sat_gdp[column]) for column in sat_gdp if column != "state"}
sd_sat
# Out:
# {'participation_2017': 0.3421286307808805,
#  'ebrw_2017': 43.9390532442382,
#  'math_2017': 84.14399324966696,
#  'total_2017': 89.00941298536914,
#  'participation_2018': 0.36724754594142633,
#  'ebrw_2018': 46.537937212558106,
#  'math_2018': 46.51518461749884,
#  'total_2018': 91.91248881408882,
#  'participation_2019': 0.38212228409240934,
#  'ebrw_2019': 45.28295043391055,
#  'math_2019': 50.24331199274188,
#  'total_2019': 95.17612305615312,
#  'gdpPerCap_2017': 0.009743311925452474,
#  'gdpPerCap_2018': 0.010054188953286147,
#  'gdpPerCap_2019': 0.010339751323591821}

# %% [markdown]
# ### States with 100% participation rate

# %%
# States with the participation of 100% for ACT 2017
act_gdp[act_gdp["participation_2017"]==1.0]
# Out:
#              state  participation_2017  composite_2017  participation_2018  \
# 0          Alabama                 1.0            19.2                1.00
# 3         Arkansas                 1.0            19.4                1.00
# 5         Colorado                 1.0            20.8                0.30
# 16        Kentucky                 1.0            20.0                1.00
# 17       Louisiana                 1.0            19.5                1.00
# 22       Minnesota                 1.0            21.5                0.99
# 23     Mississippi                 1.0            18.6                1.00
# 24        Missouri                 1.0            20.4                1.00
# 25         Montana                 1.0            20.3                1.00
# 27          Nevada                 1.0            17.8                1.00
# 32  North Carolina                 1.0            19.1                1.00
# ...

# %%
# States with the participation of 100% for ACT 2018
act_gdp[act_gdp["participation_2018"]==1.0]
# Out:
#              state  participation_2017  composite_2017  participation_2018  \
# 0          Alabama                1.00            19.2                 1.0
# 3         Arkansas                1.00            19.4                 1.0
# 16        Kentucky                1.00            20.0                 1.0
# 17       Louisiana                1.00            19.5                 1.0
# 23     Mississippi                1.00            18.6                 1.0
# 24        Missouri                1.00            20.4                 1.0
# 25         Montana                1.00            20.3                 1.0
# 26        Nebraska                0.84            21.4                 1.0
# 27          Nevada                1.00            17.8                 1.0
# 32  North Carolina                1.00            19.1                 1.0
# 34            Ohio                0.75            22.0                 1.0
# ...

# %%
# States with the participation of 100% for ACT 2019
act_gdp[act_gdp["participation_2019"]==1.0]
# Out:
#              state  participation_2017  composite_2017  participation_2018  \
# 0          Alabama                1.00            19.2                 1.0
# 3         Arkansas                1.00            19.4                 1.0
# 16        Kentucky                1.00            20.0                 1.0
# 17       Louisiana                1.00            19.5                 1.0
# 23     Mississippi                1.00            18.6                 1.0
# 25         Montana                1.00            20.3                 1.0
# 26        Nebraska                0.84            21.4                 1.0
# 27          Nevada                1.00            17.8                 1.0
# 32  North Carolina                1.00            19.1                 1.0
# 34            Ohio                0.75            22.0                 1.0
# 35        Oklahoma                1.00            19.4                 1.0
# ...

# %% [markdown]
# ### States with lowest ACT participation

# %%
# Sort by lowest 2017 ACT participation
act_gdp.sort_values('participation_2017', ascending=True).head()
# Out:
#             state  participation_2017  composite_2017  participation_2018  \
# 18          Maine                0.08            24.3                0.07
# 7        Delaware                0.18            24.1                0.17
# 28  New Hampshire                0.18            25.5                0.16
# 38   Rhode Island                0.21            24.0                0.15
# 37   Pennsylvania                0.23            23.7                0.20
#
#     composite_2018  participation_2019  composite_2019  gdpPerCap_2017  \
# 18            24.0                0.06            24.3        0.042456
# 7             23.8                0.13            24.1        0.063545
# 28            25.1                0.14            25.0        0.054944
# 38            24.2                0.12            24.7        0.049834
# 37            23.5                0.17            23.6        0.054290
#
#     gdpPerCap_2018  gdpPerCap_2019
# 18        0.043448        0.044215
# ...

# %%
# Sort by lowest 2017 ACT participation
act_gdp.sort_values('participation_2018', ascending=True).head()
# Out:
#             state  participation_2017  composite_2017  participation_2018  \
# 18          Maine                0.08            24.3                0.07
# 38   Rhode Island                0.21            24.0                0.15
# 28  New Hampshire                0.18            25.5                0.16
# 7        Delaware                0.18            24.1                0.17
# 37   Pennsylvania                0.23            23.7                0.20
#
#     composite_2018  participation_2019  composite_2019  gdpPerCap_2017  \
# 18            24.0                0.06            24.3        0.042456
# 38            24.2                0.12            24.7        0.049834
# 28            25.1                0.14            25.0        0.054944
# 7             23.8                0.13            24.1        0.063545
# 37            23.5                0.17            23.6        0.054290
#
#     gdpPerCap_2018  gdpPerCap_2019
# 18        0.043448        0.044215
# ...

# %% [markdown]
# Observation:
# * Maine, Rhode Island and New Hampshire remains as one of the lowest ACT participation between 2017 and 2018.

# %% [markdown]
# ### Change in participation rate

# %%
# Create new column to find change in ACT participation rate
# The columns will be added to the data dictionary
act_gdp['act_part_change_17_to_18'] = act_gdp['participation_2018'] - act_gdp['participation_2017']
act_gdp['act_part_change_18_to_19'] = act_gdp['participation_2019'] - act_gdp['participation_2018']

# Create new column to find change in SAT participation rate
sat_gdp['sat_part_change_17_to_18'] = sat_gdp['participation_2018'] - sat_gdp['participation_2017']
sat_gdp['sat_part_change_18_to_19'] = sat_gdp['participation_2019'] - sat_gdp['participation_2018']

# %%
# Find the largest change in ACT participation rate
act_gdp.nlargest(5, 'act_part_change_17_to_18')
# Out:
#        state  participation_2017  composite_2017  participation_2018  \
# 34      Ohio                0.75            22.0                1.00
# 26  Nebraska                0.84            21.4                1.00
# 2    Arizona                0.62            19.7                0.66
# 19  Maryland                0.28            23.6                0.31
# 36    Oregon                0.40            21.8                0.42
#
#     composite_2018  participation_2019  composite_2019  gdpPerCap_2017  \
# 34            20.3                1.00            20.0        0.050665
# 26            20.1                1.00            20.0        0.059752
# 2             19.2                0.73            19.0        0.042938
# 19            22.5                0.28            22.3        0.060871
# 36            21.3                0.42            21.1        0.049653
#
#     gdpPerCap_2018  gdpPerCap_2019  act_part_change_17_to_18  \
# ...

# %% [markdown]
# Observation:
# * Between 2017 to 2018, Ohio and Nebraska saw a big increase in ACT participation rate of 75% to 100% and 84% to 100% respectively.
# * ACT were either mandated or paid for in these state, explaining the increased in participation

# %%
# Find the largest change in SAT participation rate
sat_gdp.nlargest(5, 'sat_part_change_17_to_18')
# Out:
#             state  participation_2017  ebrw_2017  math_2017  total_2017  \
# 12       Illinois                0.09        559        556        1115
# 5        Colorado                0.11        606        595        1201
# 38   Rhode Island                0.71        539        524        1062
# 47  West Virginia                0.14        558        528        1086
# 29     New Jersey                0.70        530        526        1056
#
#     participation_2018  ebrw_2018  math_2018  total_2018  participation_2019  \
# 12                0.99        513        506        1019                1.00
# 5                 1.00        519        506        1025                1.00
# 38                0.97        513        505        1018                1.00
# 47                0.28        513        486         999                0.99
# 29                0.82        547        547        1094                0.82
#
# ...

# %% [markdown]
# Observation:
# * Illinois and Colorado saw the biggest increase in SAT participation from 2017 to 2018 of 90% and 89%.
# * This is supported by the state's policy of mandating SAT in 2017

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# ### Correlation heatmap

# %%
# Heatmap to show correlation between ACT participation, GDP and composite score from 2017 to 2019.
corr = act_gdp.corr()

mask = np.triu(np.ones_like(corr, dtype=bool))
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, annot = True);

# %% [markdown]
# Interpretation:
# * There is strong negative correlation between composite score and participation. In other words, the ACT composite scores goes down as the participation rate increases.
# * There is a slight correlation between GDP per capita of a state and the ACT composite score.

# %%
# Heatmap to show correlation between SAT participation, GDP and total score from 2017 to 2019.

corr = sat_gdp[["state", 
         "participation_2017", "total_2017", 
         "participation_2018", "total_2018", 
         "participation_2019", "total_2019",
         "gdpPerCap_2017", "gdpPerCap_2018", "gdpPerCap_2019"]].corr()

mask = np.triu(np.ones_like(corr, dtype=bool))
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, annot = True);

# %% [markdown]
# Interpretation:
# * Similar to ACT, there is negative correlation between total score and participation.
# * Compared to ACT, the correlation between the GDP per capita and the SAT total score is weak.

# %% [markdown]
# ### Distribution of participation rate

# %%
# Generate distribution of participation rate for ACT and SAT
# Set a subplot
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(11,7))
fig.suptitle('Distribution of Participation Percentage', fontsize = 20)

# PLot 1: Partipcipation % for ACT in 2017
ax1 = plt.subplot(2,3,1)
ax1.hist(act_gdp["participation_2017"])
ax1.set_title("Participation for ACT in 2017")
ax1.set_xlabel("Participation %")
ax1.set_ylabel("Frequency")

# PLot 2: Partipcipation % for ACT in 2018
ax2 = plt.subplot(2,3,2)
ax2.hist(act_gdp["participation_2018"])
ax2.set_title("Participation for ACT in 2018")
ax2.set_xlabel("Participation %")

# PLot 3: Partipcipation % for ACT in 2019
ax3 = plt.subplot(2,3,3)
ax3.hist(act_gdp["participation_2019"])
ax3.set_title("Participation for ACT in 2019")
ax3.set_xlabel("Participation %")

# PLot 4: Partipcipation % for SAT in 2017
ax4 = plt.subplot(2,3,4)
ax4.hist(sat_gdp["participation_2017"])
ax4.set_title("Participation for SAT in 2017")
ax4.set_xlabel("Participation %")
ax4.set_ylabel("Frequency")

# PLot 5: Partipcipation % for SAT in 2018
ax5 = plt.subplot(2,3,5)
ax5.hist(sat_gdp["participation_2018"])
ax5.set_title("Participation for SAT in 2018")
ax5.set_xlabel("Participation %")

# PLot 6: Partipcipation % for SAT in 2019
ax6 = plt.subplot(2,3,6)
ax6.hist(sat_gdp["participation_2019"])
ax6.set_title("Participation for SAT in 2019")
ax6.set_xlabel("Participation %")

fig.tight_layout()

# %% [markdown]
# Interpretation:
# * Participation rate for SAT and ACT are not normally distributed and is observed to skewed towards either the left or right

# %% [markdown]
# ### Box plot of ACT/SAT Score

# %%
# Box plot for SAT score
plt.boxplot([sat_gdp["total_2017"],
            sat_gdp["total_2018"],
            sat_gdp["total_2019"]],
            labels=["2017", "2018", "2019"]);
plt.title("SAT score");

# %% [markdown]
# Interpretation:
# * The SAT scores shares a similar spread and centre (Interquartile range and mean) for all three years
# * 2019 SAT has a lower minimium score compared to 2017 and 2018

# %%
# Box plot for ACT score
plt.boxplot([act_gdp["composite_2017"],
            act_gdp["composite_2018"],
            act_gdp["composite_2019"]],
            labels=["2017", "2018", "2019"]);
plt.title("ACT score");

# %% [markdown]
# Interpretation:
# * The ACT shares a similar spread and centre for all 3 years.
# * 2017 ACT is observed to have a higher mean

# %% [markdown]
# ### Relationship between participation rate and ACT/SAT scores

# %%
# To find out if there is any correlation between participation and ACT/SAT score
# Based on background research, only several states mandates ACT/SAT score.
# Set a subplot
fig, axs = plt.subplots(2,1, figsize=(8,8))
fig.suptitle('Participation Percentage vs ACT Composite Score', fontsize = 20)

# Plot 1: Participation and Composite for 2017
ax1 = plt.subplot(2,2,2)
ax1.scatter(act_gdp["participation_2017"], act_gdp["composite_2017"])
ax1.set_title("Participation for ACT in 2017")
ax1.set_xlabel("Participation %")
ax1.set_ylabel("ACT Composite Score")

# Plot 2: Participation and Composite 2018
ax2 = plt.subplot(2,2,3)
plt.scatter(act_gdp["participation_2018"], act_gdp["composite_2018"])
ax2.set_title("Participation for ACT in 2018")
ax2.set_xlabel("Participation %")
ax2.set_ylabel("ACT Composite Score")

# Plot 3: Participation and Composite 2019
ax3 = plt.subplot(2,2,4)
plt.scatter(act_gdp["participation_2019"], act_gdp["composite_2019"])
ax3.set_title("Participation for ACT in 2019")
ax3.set_xlabel("Participation %")
ax3.set_ylabel("ACT Composite Score")

fig.tight_layout()
plt.show()

# %% [markdown]
# Interpretation:
# * As observed in the heatmap above, there is negative correlation between Participation percentages and ACT composite score for all 3 years.
# * Some of the highest scores are achieved by states with the lowest participation rate

# %%
# Participation % vs SAT score
# Set a subplot
fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(8,8))
fig.suptitle('Participation Percentage vs SAT Total Score', fontsize = 20)

# Plot 1: Participation and SAT total score for 2017
ax1 = plt.subplot(2,2,2)
ax1.scatter(sat_gdp["participation_2017"], sat_gdp["total_2017"])
ax1.set_title("Participation for SAT in 2017")
ax1.set_xlabel("Participation %")
ax1.set_ylabel("SAT Total Score")

# Plot 2: Participation and SAT total score for 2018
ax2 = plt.subplot(2,2,3)
ax2.scatter(sat_gdp["participation_2018"], sat_gdp["total_2018"])
ax2.set_title("Participation for SAT in 2018")
ax2.set_xlabel("Participation %")
ax2.set_ylabel("SAT Total Score")

# Plot 3: Participation and SAT total score for 2019
ax3 = plt.subplot(2,2,4)
ax3.scatter(sat_gdp["participation_2019"], sat_gdp["total_2019"])
ax3.set_title("Participation for SAT in 2019")
ax3.set_xlabel("Participation %")
ax3.set_ylabel("SAT Total Score")

fig.tight_layout()
plt.show()

# %% [markdown]
# Interpretation:
# * Similar to ACT, there is negative correlation between Participation percentages and SAT total score for all 3 years.
# * However, there are a number of states where some of the lowest participation states achieved the lowest score. This can be seen in 2018 and 2019 SAT.

# %% [markdown]
# ### Relationship between GDP per capita and participation rate

# %%
# We wish to explore if there is any correlation between GDP per capita and participation rate
# GDP vs Participation
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(12,8))
fig.suptitle('GDP vs ACT/ SAT Participation Rate', fontsize = 20)

# Plot 1: GDP vs ACT Participation 2017
ax1 = plt.subplot(2,3,1)
ax1.scatter(act_gdp["gdpPerCap_2017"], act_gdp["participation_2017"])
ax1.set_title("GDP Against ACT Participation %")
ax1.set_xlabel("GDP Per Capital (2017)")
ax1.set_ylabel("Participation %")

# Plot 2: GDP vs ACT Participation 2018
ax2 = plt.subplot(2,3,2)
ax2.scatter(act_gdp["gdpPerCap_2018"], act_gdp["participation_2018"])
ax2.set_title("GDP Against ACT Participation %")
ax2.set_xlabel("GDP Per Capital (2018)")

# Plot 3: GDP vs ACT Participation 2018
ax3 = plt.subplot(2,3,3)
ax3.scatter(act_gdp["gdpPerCap_2019"], act_gdp["participation_2019"])
ax3.set_title("GDP Against ACT Participation %")
ax3.set_xlabel("GDP Per Capital (2019)")

# Plot 4: GDP vs SAT Participation 2017
ax4 = plt.subplot(2,3,4)
ax4.scatter(sat_gdp["gdpPerCap_2017"], sat_gdp["participation_2017"])
ax4.set_title("GDP Against SAT Participation %")
ax4.set_xlabel("GDP Per Capital (2017)")
ax4.set_ylabel("Participation %")

# Plot 5: GDP vs SAT Participation 2018
ax5 = plt.subplot(2,3,5)
ax5.scatter(sat_gdp["gdpPerCap_2018"], sat_gdp["participation_2018"])
ax5.set_title("GDP Against SAT Participation %")
ax5.set_xlabel("GDP Per Capital (2018)")

# Plot 6: GDP vs SAT Participation 2019
ax6 = plt.subplot(2,3,6)
ax6.scatter(sat_gdp["gdpPerCap_2019"], sat_gdp["participation_2019"])
ax6.set_title("GDP Against SAT Participation %")
ax6.set_xlabel("GDP Per Capital (2019)")

fig.tight_layout()
plt.show()

# %% [markdown]
# Interpretation:
# * No relationship is observed between GDP and Participation Rate across ACT and SAT

# %% [markdown]
# ### Relationship between GDP per capita and ACT/SAT score

# %%
# This relationship would answer to our problem statement to see if there are significant correlation between GDP per capita and ACT/SAT scores
# GDP vs ACT/ SAT score
# Set a subplot
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(12,8))
fig.suptitle('GDP Per Capita vs ACT/ SAT score', fontsize = 20)

# Plot 1: GDP and ACT score for 2017
ax1 = plt.subplot(2,3,1)
ax1.scatter(act_gdp["gdpPerCap_2017"], act_gdp["composite_2017"])
ax1.set_title("ACT 2017")
ax1.set_xlabel("GDP Per Capita")
ax1.set_ylabel("ACT Composite Score")

# Plot 2: GDP and ACT score for 2018
ax2 = plt.subplot(2,3,2)
ax2.scatter(act_gdp["gdpPerCap_2018"], act_gdp["composite_2018"])
ax2.set_title("ACT 2018")
ax2.set_xlabel("GDP Per Capita")

# Plot 3: GDP and ACT score for 2019
ax3 = plt.subplot(2,3,3)
ax3.scatter(act_gdp["gdpPerCap_2019"], act_gdp["composite_2019"])
ax3.set_title("ACT 2019")
ax3.set_xlabel("GDP Per Capita")

# Plot 4: GDP and SAT score for 2017
ax4 = plt.subplot(2,3,4)
ax4.scatter(sat_gdp["gdpPerCap_2017"], sat_gdp["total_2017"])
ax4.set_title("SAT 2017")
ax4.set_xlabel("GDP Per Capita")
ax4.set_ylabel("SAT Total Score")

# Plot 5: GDP and SAT score for 2018
ax5 = plt.subplot(2,3,5)
ax5.scatter(sat_gdp["gdpPerCap_2018"], sat_gdp["total_2018"])
ax5.set_xlabel("GDP Per Capita")
ax5.set_title("SAT 2018")

# Plot 6: GDP and SAT score for 2019
ax6 = plt.subplot(2,3,6)
ax6.scatter(sat_gdp["gdpPerCap_2019"], sat_gdp["total_2019"])
ax6.set_xlabel("GDP Per Capita")
ax6.set_title("SAT 2019")

fig.tight_layout()
plt.show()

# %% [markdown]
# Interpretation:
# * There is a moderate correlation between ACT composite and GDP per capita. In other words, as GDP per capita increases, the average score of ACT increases.
# * However, there is no significant correlation between SAT total score and GPA per capita.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# From the state, a moderate correlation is seen between ACT composite score and GDP per capita. In other words, as GDP per capita increases, the average score of ACT increases. However, the same observation could not be seen for SAT.
#
# There is also a distinct negative correlation between participation rates and test scores. As participation rate increases, the lower the ACT/SAT test scores. There is no correlation between GDP per capita and participation rate by state. As a result, it is not necessary to channel additional to poorer states to boost participation. If the College Board aims to solely increase participation rate, it is recommended consider implementing a single, standardised test. This could also be beneficial to both the students and the educational system as it would serve as a benchmark to measure the efficacy of the school. Students could be benefitted in guiding them to appropriate schools.For example, if SAT is mandated in a certain state, the participation rate of ACT is considerably low.
#
# However, keeping in mind that as participation increases, the lower the test score. To aid students in achieving better grades, additional resources could be provided to students from lower-income states, such as subsidies or tuitution grant. Schools could also consider highlighting the importance of the test during school circularium.

# %% [markdown]
# ### Limitation

# %% [markdown]
# The participation rate for ACT/SAT varies from just 2% to 100%, it should be worth considering the existance of sampling bias in how students decides to participate in the selected test.

# %% [markdown]
# ### Additional Data

# %% [markdown]
# To better understand the relationship between socioeconomic status, average scores and participation rate, useful dataset could include:
# * Educational budget by state
# * The number of universities requiring ACT/SAT test results by state
# * University admission results based on SAT/ACT scores by state
